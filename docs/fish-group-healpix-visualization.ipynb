# %%
import xarray as xr
import xdggs

# %%
data = xr.open_zarr("../data/test_pollock_average.zarr")

# %%
data = data.set_xindex("cell_ids", xdggs.DGGSIndex)

# %%
data = data.pipe(xdggs.decode)

# %%
data
# Out:
# <xarray.Dataset> Size: 73MB
# Dimensions:     (cell: 1815861, quarter: 4)
# Coordinates:
#   * cell_ids    (cell) int64 15MB dask.array<chunksize=(1815861,), meta=np.ndarray>
#   * quarter     (quarter) int64 32B 1 2 3 4
#     resolution  float64 8B ...
# Dimensions without coordinates: cell
# Data variables:
#     states      (quarter, cell) float64 58MB dask.array<chunksize=(1, 1815861), meta=np.ndarray>
# Indexes:
#     cell_ids  HealpixIndex(nside=12, indexing_scheme=nested)

# %%
data.dggs.coord.data
# Out:
# dask.array<open_dataset-cell_ids, shape=(1815861,), dtype=int64, chunksize=(1815861,), chunktype=numpy.ndarray>

# %%
data.cell_ids
# Out:
# <xarray.DataArray 'cell_ids' (cell: 1815861)> Size: 15MB
# dask.array<open_dataset-cell_ids, shape=(1815861,), dtype=int64, chunksize=(1815861,), chunktype=numpy.ndarray>
# Coordinates:
#   * cell_ids    (cell) int64 15MB dask.array<chunksize=(1815861,), meta=np.ndarray>
#     resolution  float64 8B ...
# Dimensions without coordinates: cell
# Indexes:
#     cell_ids  HealpixIndex(nside=12, indexing_scheme=nested)
# Attributes:
#     grid_name:  healpix
#     nest:       True
#     nside:      4096

# %%
data["states"].isel(quarter=0).dggs.explore()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data["states"].isel(quarter=0).dggs.explore()
#
# File ~/micromamba/envs/devseed/lib/python3.12/site-packages/xdggs/accessor.py:180, in DGGSAccessor.explore(self, cmap, center, alpha)
#     177     raise ValueError("does not work with Dataset objects, yet")
#     179 cell_dim = self._obj[self._name].dims[0]
# --> 180 return explore(
#     181     self._obj,
#     182     cell_dim=cell_dim,
#     183     cmap=cmap,
#     184     center=center,
#     185     alpha=alpha,
#     186 )
#
# File ~/micromamba/envs/devseed/lib/python3.12/site-packages/xdggs/plotting.py:62, in explore(arr, cell_dim, cmap, center, alpha)
#      59 cell_ids = arr.dggs.coord.data
#      60 grid_info = arr.dggs.grid_info
# ---> 62 polygons = grid_info.cell_boundaries(cell_ids, backend="geoarrow")
# ...

# %%
# Error happens when internally its trying this
data.dggs.grid_info.cell_boundaries(data.dggs.coord.data)
